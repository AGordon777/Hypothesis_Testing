# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Always state the H0 and H1 before conducting the hypothesis test.
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents.

# %%
salaries = pd.read_csv('Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
salaries.head(10)
# Out:
#                       Name                               Job Titles  \
# 0   ADRIANO,  RACQUEL ANNE                                PARAMEDIC
# 1        AFFANEH,  MAHIR A                           POLICE OFFICER
# 2        AFOENYI,  PHYLLIS                TITLE V PROGRAM TRAINEE I
# 3          AGAR,  BULENT B                      DEPUTY COMMISSIONER
# 4          AGEE,  LAWRENCE                           POLICE OFFICER
# 5        AGNEW,  ANTONIO E                       MOTOR TRUCK DRIVER
# 6        AGNEW,  MELISSA M                                 SERGEANT
# 7        AGOSTA,  JOSEPH J   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 8  AGOSTINELLI,  MICHAEL A  FIREFIGHTER (PER ARBITRATORS AWARD)-EMT
# 9        AGOSTINI,  LUIS R                                 ASST DIR
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0              FIRE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# ...

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
display(salaries.isna().sum())
salaries.isna().sum() / len(salaries)
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        25528
# Annual Salary         8174
# Hourly Rate          25528
# dtype: int64
# Name                 0.000000
# Job Titles           0.000000
# Department           0.000000
# Full or Part-Time    0.000000
# Salary or Hourly     0.000000
# Typical Hours        0.757462
# Annual Salary        0.242538
# Hourly Rate          0.757462
# dtype: float64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
salaries['Salary or Hourly'].value_counts(dropna=False)
# Out:
# Salary    25528
# Hourly     8174
# Name: Salary or Hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
print('Number of departments: ', salaries['Department'].nunique())
salaries['Department'].value_counts(dropna=False)
# Out:
# Number of departments:  36
# POLICE                 13848
# FIRE                    4627
# STREETS & SAN           2175
# WATER MGMNT             1914
# AVIATION                1856
# OEMC                    1737
# TRANSPORTN              1113
# PUBLIC LIBRARY          1088
# DAIS                    1033
# FAMILY & SUPPORT         656
# FINANCE                  544
# HEALTH                   467
# LAW                      398
# CITY COUNCIL             362
# BUILDINGS                258
# PUBLIC SAFETY ADMIN      244
# BUSINESS AFFAIRS         167
# HOUSING & ECON DEV       154
# COPA                     123
# BOARD OF ELECTION        111
# MAYOR'S OFFICE           104
# INSPECTOR GEN             95
# CITY CLERK                88
# PROCUREMENT               84
# HUMAN RESOURCES           75
# ANIMAL CONTRL             75
# CULTURAL AFFAIRS          74
# HOUSING                   66
# BUDGET & MGMT             44
# ADMIN HEARNG              38
# DISABILITIES              28
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Null H0: The hourly wage of all hourly workers is equal to $30/hr. salaries['Hourly Rate'].mean() - 30 = 0
# H1: The hourly wage of all hourly workers is not equal to $30/hr. salaries['Hourly Rate'].mean() - 30 <> 0
# alpha is 0.05

hourly = salaries[salaries['Salary or Hourly'] == 'Hourly'].copy()
display(hourly.head())

from scipy.stats import ttest_1samp

stat, pval = ttest_1samp(hourly['Hourly Rate'], 30)

print('stat is  ', round(stat, 2))
print('pvalue for the two-tailed test is ', pval)
# Out:
#                       Name                 Job Titles        Department  \
# 2        AFOENYI,  PHYLLIS  TITLE V PROGRAM TRAINEE I  FAMILY & SUPPORT
# 5        AGNEW,  ANTONIO E         MOTOR TRUCK DRIVER          AVIATION
# 15      AGSALUD,  FERNAN S         SANITATION LABORER     STREETS & SAN
# 16  AGSALUD JR,  JUANITO S         SANITATION LABORER     STREETS & SAN
# 21         AGUAYO,  LUIS M       LABORER - APPRENTICE       WATER MGMNT
#
#    Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 2                  P           Hourly           20.0            NaN
# 5                  F           Hourly           40.0            NaN
# 15                 F           Hourly           40.0            NaN
# 16                 F           Hourly           40.0            NaN
# 21                 F           Hourly           40.0            NaN
#
#     Hourly Rate
# 2         13.00
# 5         37.45
# 15        40.78
# 16        38.52
# 21        34.98
# stat is   31.21
# ...

# %% [markdown]
# This suggests that the null hypothesis can be rejected. This sample data suggests that the mean hourly salary is not $30/hr.
#
# Further, the positive stat value suggests that the true mean is greater than $30/hr.

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our Null hypothesis is less than or equal to, then to reject, the test statistic must be positive (rejects the <) and the p-value below 0.05 (rejects the =).

# %%
# Null H0: The salary of all salaried workers in the police force is less than or equal to $86. salaried_police['Annual Salary'].mean() - 86000 <= 0
# H1: The salary of all salaried workers in the police force is greater than $86k. salaried_police['Annual Salary'].mean() - 86000 > 0
# alpha is 0.05

salaried_police = salaries[(salaries['Salary or Hourly'] == 'Salary') & (salaries['Department'] == 'POLICE')].copy()
display(salaried_police.head())

stat1, pval1 = ttest_1samp(salaried_police['Annual Salary'], 86000)

print('stat is  ', round(stat1, 2))
print('pvalue for the one-tailed test is ', pval1 / 2)

salaried_police['Annual Salary'].mean()
# Out:
#                 Name                              Job Titles Department  \
# 1  AFFANEH,  MAHIR A                          POLICE OFFICER     POLICE
# 4    AGEE,  LAWRENCE                          POLICE OFFICER     POLICE
# 6  AGNEW,  MELISSA M                                SERGEANT     POLICE
# 7  AGOSTA,  JOSEPH J  POLICE OFFICER (ASSIGNED AS DETECTIVE)     POLICE
# 9  AGOSTINI,  LUIS R                                ASST DIR     POLICE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 1                 F           Salary            NaN        93354.0
# 4                 F           Salary            NaN        90024.0
# 6                 F           Salary            NaN       111444.0
# 7                 F           Salary            NaN       103932.0
# 9                 F           Salary            NaN        95736.0
#
#    Hourly Rate
# 1          NaN
# 4          NaN
# 6          NaN
# 7          NaN
# 9          NaN
# stat is   18.52
# ...

# %% [markdown]
# Again, the p-value is so low that the null hypothesis should be rejected.
#
# stat1 is positive, suggesting that the true mean is above $86k supporting the chief's statement.

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
pd.crosstab(salaries['Department'], salaries['Salary or Hourly'], dropna=False).sort_values(by= 'Hourly', ascending = False)
# Out:
# Salary or Hourly     Hourly  Salary
# Department
# STREETS & SAN          1846     329
# WATER MGMNT            1558     356
# AVIATION               1214     642
# OEMC                   1077     660
# DAIS                    745     288
# TRANSPORTN              726     387
# FAMILY & SUPPORT        357     299
# PUBLIC LIBRARY          356     732
# CITY COUNCIL             74     288
# LAW                      48     350
# PUBLIC SAFETY ADMIN      48     196
# FINANCE                  45     499
# POLICE                   24   13824
# MAYOR'S OFFICE           17      87
# ANIMAL CONTRL            12      63
# CULTURAL AFFAIRS         10      64
# BUSINESS AFFAIRS          7     160
# HOUSING & ECON DEV        3     151
# PROCUREMENT               2      82
# HEALTH                    2     465
# BUDGET & MGMT             2      42
# DISABILITIES              1      27
# POLICE BOARD              0       2
# TREASURER                 0      28
# ...

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Null H0: The salary of hourly workers in the STREETS & SAN department is is greater than or equal to $35/hour. hourly_streets['Hourly Rate'].mean() - 35 >= 0
# H1: The salary of hourly workers in the STREETS & SAN department is less than $35/hour. hourly_streets['Hourly Rate'].mean() - 35 < 0
# alpha is 0.05

hourly_streets = salaries[(salaries['Salary or Hourly'] == 'Hourly') & (salaries['Department'] == 'STREETS & SAN')].copy()
display(hourly_streets.head())

stat2, pval2 = ttest_1samp(hourly_streets['Hourly Rate'], 35)

print('stat is  ', round(stat2, 2))
print('pvalue for the one-tailed test is ', pval2 / 2)

hourly_streets['Hourly Rate'].mean()
# Out:
#                       Name               Job Titles     Department  \
# 15      AGSALUD,  FERNAN S       SANITATION LABORER  STREETS & SAN
# 16  AGSALUD JR,  JUANITO S       SANITATION LABORER  STREETS & SAN
# 26        AGUILAR,  EFRAIN       SANITATION LABORER  STREETS & SAN
# 49  ABDUL-SHAKUR,  TAHIR J  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# 65       ABRAMS,  SAMUEL A  POOL MOTOR TRUCK DRIVER  STREETS & SAN
#
#    Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 15                 F           Hourly           40.0            NaN
# 16                 F           Hourly           40.0            NaN
# 26                 F           Hourly           40.0            NaN
# 49                 P           Hourly           10.0            NaN
# 65                 F           Hourly           40.0            NaN
#
#     Hourly Rate
# 15        40.78
# 16        38.52
# 26        38.52
# 49        29.96
# 65        37.45
# stat is   4.0
# ...

# %% [markdown]
# The null hypothesis can be rejected.
#
# Positive stat suggests that the true hourly rate is above $35/hr.

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
import scipy.stats

confidence_level = 0.95

degrees_freedom = len(hourly) - 1

sample_mean = np.mean(hourly['Hourly Rate'])

sample_standard_error = scipy.stats.sem(hourly['Hourly Rate'])

confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

print( 'confidence interval is ', confidence_interval )
# Out:
# confidence interval is  (34.29839539204317, 34.874504045196865)

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
confidence_level1 = 0.95

degrees_freedom1 = len(salaried_police) - 1

sample_mean1 = np.mean(salaried_police['Annual Salary'])

sample_standard_error1 = scipy.stats.sem(salaried_police['Annual Salary'])

confidence_interval1 = scipy.stats.t.interval(confidence_level1, 
                                             degrees_freedom1, 
                                             sample_mean1, 
                                             sample_standard_error1)

print( 'confidence interval is ', confidence_interval1 )
# Out:
# confidence interval is  (88534.1182885883, 89134.11955863392)

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Null H0: The proportion of employees on hourly contracts is 25%.
# H1: The proportion of employees on hourly contracts is not 25%.
# alpha is 0.05

from statsmodels.stats.proportion import proportions_ztest

zstat, pval3 = proportions_ztest(len(hourly), len(salaries), value=0.25, alternative='two-sided', prop_var=False)

print('zstat is  ', round(zstat, 2))
print('pvalue for the two-tailed test is ', pval3)

len(hourly) / len(salaries)
# Out:
# zstat is   -3.2
# pvalue for the two-tailed test is  0.0013922864704323116
# 0.24253753486439975
